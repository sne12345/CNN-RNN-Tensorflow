# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

import PIL
import matplotlib.image as img
import matplotlib.pyplot as plt

from visual import *
from plotter import *

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Input,  MaxPooling2D, GlobalMaxPooling2D, ZeroPadding2D, AveragePooling2D, GlobalAveragePooling2D, BatchNormalization, Activation, add
from tensorflow.keras.models import Model

# %%
def load_data(path):
    return pd.read_csv(path)

def load_images(path, names):
    
    images= [ PIL.Image.open(path + name) for name in names ]
    
    return images

def images2numpy(images, size):

    output = [np.array(im.resize(size)) for im in images]
    
    output = np.array(output)
    
    return output
 
def get_images_and_preprocessing(img_size):
    
    CSV_PATH = "./Chinese-Traffic-Sign/annotations.csv"
    IMG_PATH = "./Chinese-Traffic-Sign/images/"
    IMG_SIZE = (img_size,img_size)

    name_caption = load_data(CSV_PATH)
    names = name_caption['file_name']
    
    images = load_images(IMG_PATH,names)
    np_images = images2numpy(images,IMG_SIZE)
   
    label_caption = load_data(CSV_PATH)
    np_labels = label_caption['category'].tolist()
    
#     print(set(np_labels))
    
    images = np_images / 255.
    labels = to_categorical(np_labels, 58)
    
    train_images, test_images, train_labels, test_labels = train_test_split(images, labels, test_size=0.4, random_state=1004)
    
    return train_images, test_images, train_labels, test_labels

# %% [markdown]
# # 1. MLP(다층 퍼셉트론 모델)

# %% [markdown]
# ### 정확도 : 0.95
# epoch = 50, batch_size = 256, image_size = 28, layer = 3 (relu, relu, softmax)

# %%
def MLP(img_size):
    
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(img_size, img_size, 3)))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(units=512,activation='relu'))
    model.add(tf.keras.layers.Dense(units=256,activation='relu'))
    model.add(tf.keras.layers.Dense(units=58,activation='softmax'))
	
    return model


def main():
    
    train_images, test_images, train_labels, test_labels = get_images_and_preprocessing(28)
    
    print(train_images.shape)
    print(type(train_images))
    
    
    # 지시사항 2에서 설정한 모델을 불러옵니다.
    model = MLP(28)
    
    # 모델의 구조를 확인합니다.
    model.summary()
    
    # 컴파일러를 설정합니다.
    model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])
    
    # fit 함수를 사용하여 모델을 학습합니다.
    # 학습 수행 시 정보는 history에 저장합니다.
    history = model.fit(train_images, train_labels, epochs=50, batch_size=256,validation_data=(test_images, test_labels),verbose=2)
    
    # evaluate 함수를 사용하여 테스트 데이터의 결과값을 저장합니다.
    loss, test_acc = model.evaluate(test_images,test_labels)
    
    print('\nTest Loss : {:.4f} | Test Accuracy : {}'.format(loss, test_acc))
    print('예측한 Test Data 클래스 : ',model.predict_classes(test_images))
    
    Visualize([('MLP', history)], 'loss')
    
    return test_acc

    
if __name__=='__main__':
    main()
# Out:
# (3698, 28, 28, 3)
# <class 'numpy.ndarray'>
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 2352)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               1204736
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_11 (Dense)             (None, 58)                14906
# =================================================================
# Total params: 1,350,970
# Trainable params: 1,350,970
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 15/15 - 1s - loss: 3.6242 - accuracy: 0.1314 - val_loss: 3.2271 - val_accuracy: 0.2137
# Epoch 2/300
# 15/15 - 0s - loss: 2.8835 - accuracy: 0.3175 - val_loss: 2.6467 - val_accuracy: 0.3755
# Epoch 3/300
# 15/15 - 0s - loss: 2.3435 - accuracy: 0.4362 - val_loss: 2.2156 - val_accuracy: 0.4457
# Epoch 4/300
# 15/15 - 0s - loss: 0.0164 - accuracy: 0.9995 - val_loss: 0.2360 - val_accuracy: 0.9505
# Epoch 74/300
# 15/15 - 0s - loss: 0.0146 - accuracy: 0.9995 - val_loss: 0.2342 - val_accuracy: 0.9513
# Epoch 75/300
# 15/15 - 0s - loss: 0.0131 - accuracy: 0.9997 - val_loss: 0.2249 - val_accuracy: 0.9562
# Epoch 76/300
# 15/15 - 0s - loss: 0.0126 - accuracy: 0.9995 - val_loss: 0.2325 - val_accuracy: 0.9538
# Epoch 77/300
# 15/15 - 0s - loss: 0.0141 - accuracy: 0.9997 - val_loss: 0.2296 - val_accuracy: 0.9542
# Epoch 78/300
# 15/15 - 0s - loss: 0.0121 - accuracy: 0.9997 - val_loss: 0.2304 - val_accuracy: 0.9534
# Epoch 79/300
# 15/15 - 0s - loss: 0.0119 - accuracy: 0.9995 - val_loss: 0.2171 - val_accuracy: 0.9546
# Epoch 80/300
# 15/15 - 0s - loss: 0.0114 - accuracy: 0.9997 - val_loss: 0.2317 - val_accuracy: 0.9546
# Epoch 81/300
# 15/15 - 0s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.2198 - val_accuracy: 0.9586
# Epoch 82/300
# 15/15 - 0s - loss: 0.0101 - accuracy: 0.9997 - val_loss: 0.2163 - val_accuracy: 0.9570
# Epoch 83/300
# 15/15 - 0s - loss: 0.0108 - accuracy: 0.9989 - val_loss: 0.2330 - val_accuracy: 0.9542
# Epoch 84/300
# 15/15 - 0s - loss: 0.0105 - accuracy: 0.9995 - val_loss: 0.2209 - val_accuracy: 0.9578
# Epoch 85/300
# 15/15 - 0s - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2156 - val_accuracy: 0.9570
# Epoch 86/300
# 15/15 - 0s - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.2199 - val_accuracy: 0.9562
# Epoch 87/300
# 15/15 - 0s - loss: 0.0095 - accuracy: 0.9995 - val_loss: 0.2293 - val_accuracy: 0.9542
# Epoch 88/300
# 15/15 - 0s - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.2191 - val_accuracy: 0.9566
# Epoch 89/300
# 15/15 - 0s - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.2214 - val_accuracy: 0.9562
# Epoch 90/300
# 15/15 - 0s - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.2334 - val_accuracy: 0.9570
# Epoch 91/300
# 15/15 - 0s - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.2277 - val_accuracy: 0.9562
# Epoch 92/300
# 15/15 - 0s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.2354 - val_accuracy: 0.9570
# Epoch 93/300
# 15/15 - 0s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.2282 - val_accuracy: 0.9566
# Epoch 94/300
# 15/15 - 0s - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.2328 - val_accuracy: 0.9526
# Epoch 95/300
# 15/15 - 0s - loss: 0.0076 - accuracy: 0.9997 - val_loss: 0.2315 - val_accuracy: 0.9562
# Epoch 96/300
# 15/15 - 0s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.2349 - val_accuracy: 0.9546
# Epoch 97/300
# 15/15 - 0s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.2337 - val_accuracy: 0.9538
# Epoch 98/300
# 15/15 - 0s - loss: 0.0088 - accuracy: 0.9992 - val_loss: 0.2296 - val_accuracy: 0.9538
# Epoch 99/300
# 15/15 - 0s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.2241 - val_accuracy: 0.9578
# Epoch 100/300
# 15/15 - 0s - loss: 0.0061 - accuracy: 0.9997 - val_loss: 0.2332 - val_accuracy: 0.9554
# Epoch 101/300
# 15/15 - 0s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2271 - val_accuracy: 0.9554
# Epoch 102/300
# 15/15 - 0s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.2271 - val_accuracy: 0.9546
# Epoch 103/300
# 15/15 - 0s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2272 - val_accuracy: 0.9521
# Epoch 104/300
# 15/15 - 0s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2355 - val_accuracy: 0.9546
# Epoch 105/300
# 15/15 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.2283 - val_accuracy: 0.9562
# Epoch 106/300
# 15/15 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.2314 - val_accuracy: 0.
- accuracy: 1.0000 - val_loss: 0.2573 - val_accuracy: 0.9578
# Epoch 203/300
# 15/15 - 0s - loss: 7.4242e-04 - accuracy: 1.0000 - val_loss: 0.2601 - val_accuracy: 0.9554
# Epoch 204/300
# 15/15 - 0s - loss: 7.0734e-04 - accuracy: 1.0000 - val_loss: 0.2604 - val_accuracy: 0.9570
# Epoch 205/300
# 15/15 - 0s - loss: 7.0895e-04 - accuracy: 1.0000 - val_loss: 0.2571 - val_accuracy: 0.9578
# Epoch 206/300
# 15/15 - 0s - loss: 7.0723e-04 - accuracy: 1.0000 - val_loss: 0.2650 - val_accuracy: 0.9570
# Epoch 207/300
# 15/15 - 0s - loss: 6.8901e-04 - accuracy: 1.0000 - val_loss: 0.2679 - val_accuracy: 0.9586
# Epoch 208/300
# 15/15 - 0s - loss: 6.8996e-04 - accuracy: 1.0000 - val_loss: 0.2603 - val_accuracy: 0.9570
# Epoch 209/300
# 15/15 - 0s - loss: 6.6776e-04 - accuracy: 1.0000 - val_loss: 0.2641 - val_accuracy: 0.9586
# Epoch 210/300
# 15/15 - 0s - loss: 6.5892e-04 - accuracy: 1.0000 - val_loss: 0.2590 - val_accuracy: 0.9562
# Epoch 211/300
# 15/15 - 0s - loss: 6.3727e-04 - accuracy: 1.0000 - val_loss: 0.2587 - val_accuracy: 0.9562
# Epoch 212/300
# 15/15 - 0s - loss: 6.4019e-04 - accuracy: 1.0000 - val_loss: 0.2630 - val_accuracy: 0.9578
# Epoch 213/300
# 15/15 - 0s - loss: 6.3478e-04 - accuracy: 1.0000 - val_loss: 0.2661 - val_accuracy: 0.9562
# Epoch 214/300
# 15/15 - 0s - loss: 6.2591e-04 - accuracy: 1.0000 - val_loss: 0.2637 - val_accuracy: 0.9586
# Epoch 215/300
# 15/15 - 0s - loss: 6.1328e-04 - accuracy: 1.0000 - val_loss: 0.2628 - val_accuracy: 0.9562
# Epoch 216/300
# 15/15 - 0s - loss: 6.0346e-04 - accuracy: 1.0000 - val_loss: 0.2658 - val_accuracy: 0.9570
# Epoch 217/300
# 15/15 - 0s - loss: 6.4455e-04 - accuracy: 1.0000 - val_loss: 0.2716 - val_accuracy: 0.9570
# Epoch 218/300
# 15/15 - 0s - loss: 6.6284e-04 - accuracy: 1.0000 - val_loss: 0.2653 - val_accuracy: 0.9562
# Epoch 219/300
# 15/15 - 0s - loss: 5.9227e-04 - accuracy: 1.0000 - val_loss: 0.2597 - val_accuracy: 0.9570
# Epoch 220/300
# 15/15 - 0s - loss: 5.6075e-04 - accuracy: 1.0000 - val_loss: 0.2640 - val_accuracy: 0.9562
# Epoch 221/300
# 15/15 - 0s - loss: 5.4922e-04 - accuracy: 1.0000 - val_loss: 0.2644 - val_accuracy: 0.9562
# Epoch 222/300
# 15/15 - 0s - loss: 5.5398e-04 - accuracy: 1.0000 - val_loss: 0.2678 - val_accuracy: 0.9562
# Epoch 223/300
# 15/15 - 0s - loss: 5.4793e-04 - accuracy: 1.0000 - val_loss: 0.2652 - val_accuracy: 0.9562
# Epoch 224/300
# 15/15 - 0s - loss: 5.4312e-04 - accuracy: 1.0000 - val_loss: 0.2688 - val_accuracy: 0.9562
# Epoch 225/300
# 15/15 - 0s - loss: 5.4513e-04 - accuracy: 1.0000 - val_loss: 0.2684 - val_accuracy: 0.9562
# Epoch 226/300
# 15/15 - 0s - loss: 5.2913e-04 - accuracy: 1.0000 - val_loss: 0.2676 - val_accuracy: 0.9562
# Epoch 227/300
# 15/15 - 0s - loss: 5.2061e-04 - accuracy: 1.0000 - val_loss: 0.2669 - val_accuracy: 0.
- accuracy: 1.0000 - val_loss: 0.2789 - val_accuracy: 0.9578
# Epoch 254/300
# 15/15 - 0s - loss: 4.1990e-04 - accuracy: 1.0000 - val_loss: 0.2745 - val_accuracy: 0.9570
# Epoch 255/300
# 15/15 - 0s - loss: 4.1953e-04 - accuracy: 1.0000 - val_loss: 0.2772 - val_accuracy: 0.9578
# Epoch 256/300
# 15/15 - 0s - loss: 3.6928e-04 - accuracy: 1.0000 - val_loss: 0.2749 - val_accuracy: 0.9562
# Epoch 257/300
# 15/15 - 0s - loss: 3.5763e-04 - accuracy: 1.0000 - val_loss: 0.2710 - val_accuracy: 0.9578
# Epoch 258/300
# 15/15 - 0s - loss: 3.5208e-04 - accuracy: 1.0000 - val_loss: 0.2719 - val_accuracy: 0.9570
# Epoch 259/300
# 15/15 - 0s - loss: 3.4539e-04 - accuracy: 1.0000 - val_loss: 0.2747 - val_accuracy: 0.9554
# Epoch 260/300
# 15/15 - 0s - loss: 3.3757e-04 - accuracy: 1.0000 - val_loss: 0.2718 - val_accuracy: 0.9554
# Epoch 261/300
# 15/15 - 0s - loss: 3.3138e-04 - accuracy: 1.0000 - val_loss: 0.2734 - val_accuracy: 0.9570
# Epoch 262/300
# 15/15 - 0s - loss: 3.2868e-04 - accuracy: 1.0000 - val_loss: 0.2773 - val_accuracy: 0.9578
# Epoch 263/300
# 15/15 - 0s - loss: 3.3794e-04 - accuracy: 1.0000 - val_loss: 0.2755 - val_accuracy: 0.9562
# Epoch 264/300
# 15/15 - 0s - loss: 3.3364e-04 - accuracy: 1.0000 - val_loss: 0.2762 - val_accuracy: 0.9570
# Epoch 265/300
# 15/15 - 0s - loss: 3.0980e-04 - accuracy: 1.0000 - val_loss: 0.2730 - val_accuracy: 0.9554
# Epoch 266/300
# 15/15 - 0s - loss: 3.1247e-04 - accuracy: 1.0000 - val_loss: 0.2800 - val_accuracy: 0.9562
# Epoch 267/300
# 15/15 - 0s - loss: 3.0503e-04 - accuracy: 1.0000 - val_loss: 0.2808 - val_accuracy: 0.9578
# Epoch 268/300
# 15/15 - 0s - loss: 3.1305e-04 - accuracy: 1.0000 - val_loss: 0.2804 - val_accuracy: 0.9554
# Epoch 269/300
# 15/15 - 0s - loss: 3.0251e-04 - accuracy: 1.0000 - val_loss: 0.2765 - val_accuracy: 0.9562
# Epoch 270/300
# 15/15 - 0s - loss: 3.0408e-04 - accuracy: 1.0000 - val_loss: 0.2762 - val_accuracy: 0.9554
# Epoch 271/300
# 15/15 - 0s - loss: 3.0044e-04 - accuracy: 1.0000 - val_loss: 0.2764 - val_accuracy: 0.9554
# Epoch 272/300
# 15/15 - 0s - loss: 3.1385e-04 - accuracy: 1.0000 - val_loss: 0.2749 - val_accuracy: 0.9570
# Epoch 273/300
# 15/15 - 0s - loss: 3.4342e-04 - accuracy: 1.0000 - val_loss: 0.2838 - val_accuracy: 0.9554
# Epoch 274/300
# 15/15 - 0s - loss: 2.9275e-04 - accuracy: 1.0000 - val_loss: 0.2802 - val_accuracy: 0.9578
# Epoch 275/300
# 15/15 - 0s - loss: 2.7832e-04 - accuracy: 1.0000 - val_loss: 0.2797 - val_accuracy: 0.9562
# Epoch 276/300
# 15/15 - 0s - loss: 2.7156e-04 - accuracy: 1.0000 - val_loss: 0.2785 - val_accuracy: 0.9554
# Epoch 277/300
# 15/15 - 0s - loss: 2.8869e-04 - accuracy: 1.0000 - val_loss: 0.2779 - val_accuracy: 0.9578
# Epoch 278/300
# 15/15 - 0s - loss: 2.7219e-04 - accuracy: 1.0000 - val_loss: 0.2792 - val_accuracy: 0.9562
# Epoch 279/300
# 15/15 - 0s - loss: 2.7060e-04 - accuracy: 1.0000 - val_loss: 0.2836 - val_accuracy: 0.9554
# Epoch 280/300
# 15/15 - 0s - loss: 2.7239e-04 - accuracy: 1.0000 - val_loss: 0.2871 - val_accuracy: 0.9578
# Epoch 281/300
# 15/15 - 0s - loss: 2.6967e-04 - accuracy: 1.0000 - val_loss: 0.2822 - val_accuracy: 0.9578
# Epoch 282/300
# 15/15 - 0s - loss: 2.7056e-04 - accuracy: 1.0000 - val_loss: 0.2834 - val_accuracy: 0.9562
# Epoch 283/300
# 15/15 - 0s - loss: 2.7393e-04 - accuracy: 1.0000 - val_loss: 0.2829 - val_accuracy: 0.9562
# Epoch 284/300
# 15/15 - 0s - loss: 2.5804e-04 - accuracy: 1.0000 - val_loss: 0.2812 - val_accuracy: 0.9570
# Epoch 285/300
# 15/15 - 0s - loss: 2.5361e-04 - accuracy: 1.0000 - val_loss: 0.2796 - val_accuracy: 0.9562
# Epoch 286/300
# 15/15 - 0s - loss: 2.5162e-04 - accuracy: 1.0000 - val_loss: 0.2827 - val_accuracy: 0.9554
# Epoch 287/300
# 15/15 - 0s - loss: 2.5399e-04 - accuracy: 1.0000 - val_loss: 0.2827 - val_accuracy: 0.9578
# Epoch 288/300
# 15/15 - 0s - loss: 2.3883e-04 - accuracy: 1.0000 - val_loss: 0.2841 - val_accuracy: 0.9554
# Epoch 289/300
# 15/15 - 0s - loss: 2.3676e-04 - accuracy: 1.0000 - val_loss: 0.2823 - val_accuracy: 0.9562
# Epoch 290/300
# 15/15 - 0s - loss: 2.3277e-04 - accuracy: 1.0000 - val_loss: 0.2805 - val_accuracy: 0.9578
# Epoch 291/300
# 15/15 - 0s - loss: 2.3173e-04 - accuracy: 1.0000 - val_loss: 0.2828 - val_accuracy: 0.9562
# Epoch 292/300
# 15/15 - 0s - loss: 2.2728e-04 - accuracy: 1.0000 - val_loss: 0.2838 - val_accuracy: 0.9562
# Epoch 293/300
# 15/15 - 0s - loss: 2.2462e-04 - accuracy: 1.0000 - val_loss: 0.2876 - val_accuracy: 0.9562
# Epoch 294/300
# 15/15 - 0s - loss: 2.2585e-04 - accuracy: 1.0000 - val_loss: 0.2862 - val_accuracy: 0.9578
# Epoch 295/300
# 15/15 - 0s - loss: 2.2289e-04 - accuracy: 1.0000 - val_loss: 0.2825 - val_accuracy: 0.9570
# Epoch 296/300
# 15/15 - 0s - loss: 2.2003e-04 - accuracy: 1.0000 - val_loss: 0.2823 - val_accuracy: 0.9578
# Epoch 297/300
# 15/15 - 0s - loss: 2.2683e-04 - accuracy: 1.0000 - val_loss: 0.2848 - val_accuracy: 0.9570
# Epoch 298/300
# 15/15 - 0s - loss: 2.1611e-04 - accuracy: 1.0000 - val_loss: 0.2916 - val_accuracy: 0.9546
# Epoch 299/300
# 15/15 - 0s - loss: 2.1061e-04 - accuracy: 1.0000 - val_loss: 0.2857 - val_accuracy: 0.9570
# Epoch 300/300
# 15/15 - 0s - loss: 2.1263e-04 - accuracy: 1.0000 - val_loss: 0.2921 - val_accuracy: 0.9570
# 78/78 [==============================] - 0s 2ms/step - loss: 0.2921 - accuracy: 0.9570
#
# Test Loss : 0.2921 | Test Accuracy : 0.9570153951644897
# 예측한 Test Data 클래스 :  [23 28  6 ...  4 28 55]

# %% [markdown]
# # 2. CNN

# %% [markdown]
# ### 정확도 : 0.95
# epoch = 50, batch_size = 256, image_size = 28, Conv = 3 (relu, relu, relu), Dense = 1(softmax)

# %%
def CNN(img_size):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(img_size,img_size,3)))
    
    model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", padding="SAME"))
    model.add(tf.keras.layers.MaxPool2D(2,padding="VALID"))
    
    model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="SAME"))
    model.add(tf.keras.layers.MaxPool2D(2, padding="VALID"))
    
    model.add(tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="SAME"))
    model.add(tf.keras.layers.MaxPool2D(2, padding="VALID"))
    
    model.add(tf.keras.layers.Flatten())
    
    model.add(tf.keras.layers.Dense(58, activation='softmax'))
    
    
    return model
    

def main():
    
    train_images, test_images, train_labels, test_labels = get_images_and_preprocessing(28)
    
    print(train_images.shape)
    print(type(train_images))
    
    
    # 지시사항 2에서 설정한 모델을 불러옵니다.
    model = CNN(28)
    
    # 모델의 구조를 확인합니다.
    model.summary()
    
    # 컴파일러를 설정합니다.
    optimizer = tf.keras.optimizers.Adam(0.001)
    model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])
    
    # fit 함수를 사용하여 모델을 학습합니다.
    # 학습 수행 시 정보는 history에 저장합니다.
    history = model.fit(train_images,train_labels, epochs=50, batch_size=256, validation_data=(test_images, test_labels), verbose = 2)
    
    # evaluate 함수를 사용하여 테스트 데이터의 결과값을 저장합니다.
    loss, test_acc = model.evaluate(test_images,test_labels, verbose=2)
    
    print('\nTest Loss : {:.4f} | Test Accuracy : {}'.format(loss, test_acc))
    print('예측한 Test Data 클래스 : ',model.predict_classes(test_images))
    
    Visualize([('CNN', history)], 'loss')
    
    Plotter(test_images, model)
    
    return test_acc

    
if __name__=='__main__':
    main()
# Out:
# (3698, 28, 28, 3)
# <class 'numpy.ndarray'>
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 28, 28, 32)        896
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 7, 7, 128)         73856
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 58)                66874
# =================================================================
# Total params: 160,122
# Trainable params: 160,122
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 15/15 - 2s - loss: 3.6768 - accuracy: 0.1128 - val_loss: 3.4730 - val_accuracy: 0.1160
# Epoch 2/50
# 15/15 - 2s - loss: 3.1967 - accuracy: 0.1947 - val_loss: 2.9380 - val_accuracy: 0.2814
# Epoch 3/50
# 15/15 - 2s - loss: 2.6808 - accuracy: 0.3099 - val_loss: 2.4792 - val_accuracy: 0.3577
# Epoch 4/50
# 15/15 - 2s - loss: 2.2379 - accuracy: 0.3929 - val_loss: 2.0841 - val_accuracy: 0.4221
# Epoch 5/50
# 15/15 - 2s - loss: 1.8560 - accuracy: 0.4789 - val_loss: 1.7767 - val_accuracy: 0.4891
# Epoch 6/50
# 15/15 - 2s - loss: 1.5411 - accuracy: 0.5703 - val_loss: 1.4567 - val_accuracy: 0.5937
# Epoch 7/50
# 15/15 - 2s - loss: 1.2526 - accuracy: 0.6549 - val_loss: 1.2633 - val_accuracy: 0.6318
# Epoch 8/50
# 15/15 - 2s - loss: 1.0439 - accuracy: 0.7180 - val_loss: 1.0560 - val_accuracy: 0.7307
# Epoch 9/50
# 15/15 - 2s - loss: 0.8370 - accuracy: 0.7783 - val_loss: 0.9323 - val_accuracy: 0.7543
# Epoch 10/50
# 15/15 - 2s - loss: 0.7046 - accuracy: 0.8148 - val_loss: 0.8345 - val_accuracy: 0.7725
# Epoch 11/50
# 15/15 - 2s - loss: 0.5916 - accuracy: 0.8407 - val_loss: 0.7410 - val_accuracy: 0.8078
# Epoch 12/50
# 15/15 - 2s - loss: 0.5094 - accuracy: 0.8618 - val_loss: 0.6784 - val_accuracy: 0.8070
# Epoch 13/50
# 15/15 - 2s - loss: 0.4171 - accuracy: 0.8899 - val_loss: 0.5520 - val_accuracy: 0.8560
# Epoch 14/50
# 15/15 - 2s - loss: 0.3475 - accuracy: 0.9102 - val_loss: 0.5385 - val_accuracy: 0.8621
# Epoch 15/50
# 15/15 - 2s - loss: 0.2992 - accuracy: 0.9213 - val_loss: 0.5025 - val_accuracy: 0.8751
# Epoch 16/50
# 15/15 - 2s - loss: 0.2629 - accuracy: 0.9329 - val_loss: 0.4866 - val_accuracy: 0.8763
# Epoch 17/50
# 15/15 - 2s - loss: 0.2260 - accuracy: 0.9416 - val_loss: 0.4550 - val_accuracy: 0.8917
# Epoch 18/50
# 15/15 - 2s - loss: 0.2013 - accuracy: 0.9497 - val_loss: 0.4116 - val_accuracy: 0.9051
# Epoch 19/50
# 15/15 - 2s - loss: 0.1742 - accuracy: 0.9584 - val_loss: 0.3826 - val_accuracy: 0.9092
# Epoch 20/50
# 15/15 - 2s - loss: 0.1677 - accuracy: 0.9616 - val_loss: 0.3737 - val_accuracy: 0.9169
# Epoch 21/50
# 15/15 - 2s - loss: 0.1371 - accuracy: 0.9700 - val_loss: 0.3666 - val_accuracy: 0.9177
# Epoch 22/50
# 15/15 - 2s - loss: 0.1167 - accuracy: 0.9730 - val_loss: 0.3730 - val_accuracy: 0.9112
# Epoch 23/50
# 15/15 - 2s - loss: 0.1033 - accuracy: 0.9776 - val_loss: 0.3278 - val_accuracy: 0.9371
# Epoch 24/50
# 15/15 - 2s - loss: 0.0905 - accuracy: 0.9830 - val_loss: 0.3321 - val_accuracy: 0.9303
# Epoch 25/50
# 15/15 - 2s - loss: 0.0832 - accuracy: 0.9840 - val_loss: 0.3398 - val_accuracy: 0.9315
# Epoch 26/50
# 15/15 - 2s - loss: 0.0761 - accuracy: 0.9859 - val_loss: 0.3311 - val_accuracy: 0.9319
# Epoch 27/50
# 15/15 - 2s - loss: 0.0675 - accuracy: 0.9876 - val_loss: 0.3227 - val_accuracy: 0.9347
# Epoch 28/50
# 15/15 - 2s - loss: 0.0634 - accuracy: 0.9854 - val_loss: 0.3155 - val_accuracy: 0.9392
# Epoch 29/50
# 15/15 - 2s - loss: 0.0574 - accuracy: 0.9881 - val_loss: 0.2982 - val_accuracy: 0.9420
# Epoch 30/50
# 15/15 - 2s - loss: 0.0443 - accuracy: 0.9919 - val_loss: 0.3035 - val_accuracy: 0.9489
# Epoch 31/50
# 15/15 - 2s - loss: 0.0426 - accuracy: 0.9927 - val_loss: 0.3181 - val_accuracy: 0.9319
# Epoch 32/50
# 15/15 - 2s - loss: 0.0526 - accuracy: 0.9854 - val_loss: 0.2882 - val_accuracy: 0.9448
# Epoch 33/50
# 15/15 - 2s - loss: 0.0449 - accuracy: 0.9919 - val_loss: 0.3260 - val_accuracy: 0.9444
# Epoch 34/50
# 15/15 - 2s - loss: 0.0315 - accuracy: 0.9949 - val_loss: 0.2985 - val_accuracy: 0.9497
# Epoch 35/50
# 15/15 - 2s - loss: 0.0272 - accuracy: 0.9968 - val_loss: 0.2784 - val_accuracy: 0.9554
# Epoch 36/50
# 15/15 - 2s - loss: 0.0246 - accuracy: 0.9978 - val_loss: 0.2985 - val_accuracy: 0.9526
# Epoch 37/50
# 15/15 - 2s - loss: 0.0239 - accuracy: 0.9978 - val_loss: 0.3067 - val_accuracy: 0.9489
# Epoch 38/50
# 15/15 - 2s - loss: 0.0256 - accuracy: 0.9970 - val_loss: 0.3126 - val_accuracy: 0.9513
# Epoch 39/50
# 15/15 - 2s - loss: 0.0301 - accuracy: 0.9946 - val_loss: 0.3055 - val_accuracy: 0.9509
# Epoch 40/50
# 15/15 - 2s - loss: 0.0347 - accuracy: 0.9932 - val_loss: 0.3394 - val_accuracy: 0.9392
# Epoch 41/50
# 15/15 - 2s - loss: 0.0369 - accuracy: 0.9922 - val_loss: 0.3116 - val_accuracy: 0.9436
# Epoch 42/50
# 15/15 - 2s - loss: 0.0278 - accuracy: 0.9946 - val_loss: 0.3424 - val_accuracy: 0.9404
# Epoch 43/50
# 15/15 - 2s - loss: 0.0499 - accuracy: 0.9922 - val_loss: 0.3002 - val_accuracy: 0.9526
# Epoch 44/50
# 15/15 - 2s - loss: 0.0234 - accuracy: 0.9962 - val_loss: 0.2924 - val_accuracy: 0.9517
# Epoch 45/50
# 15/15 - 2s - loss: 0.0215 - accuracy: 0.9978 - val_loss: 0.3072 - val_accuracy: 0.9481
# Epoch 46/50
# 15/15 - 2s - loss: 0.0215 - accuracy: 0.9954 - val_loss: 0.3062 - val_accuracy: 0.9497
# Epoch 47/50
# 15/15 - 2s - loss: 0.0174 - accuracy: 0.9981 - val_loss: 0.2893 - val_accuracy: 0.9550
# Epoch 48/50
# 15/15 - 2s - loss: 0.0139 - accuracy: 0.9989 - val_loss: 0.3015 - val_accuracy: 0.9534
# Epoch 49/50
# 15/15 - 2s - loss: 0.0121 - accuracy: 0.9989 - val_loss: 0.3043 - val_accuracy: 0.9570
# Epoch 50/50
# 15/15 - 2s - loss: 0.0095 - accuracy: 0.9997 - val_loss: 0.3040 - val_accuracy: 0.9542
# 78/78 - 0s - loss: 0.3040 - accuracy: 0.9542
#
# Test Loss : 0.3040 | Test Accuracy : 0.9541767835617065
# 예측한 Test Data 클래스 :  [23 28  6 ...  4 28 55]
# 레이어 이름:  conv2d_6
# 레이어 이름:  max_pooling2d_6
# 레이어 이름:  conv2d_7
# 레이어 이름:  max_pooling2d_7
# 레이어 이름:  conv2d_8
# 레이어 이름:  max_pooling2d_8

# %% [markdown]
# # 3. LeNet

# %% [markdown]
# ### 정확도 : 0.95
# epoch = 20, batch_size = 2, image_size = 128, Conv = 3 + Pooling = 3 (relu, relu, relu), Dense = 3 (relu,relu,softmax)

# %%
def LeNet(img_size):
    model = keras.Sequential()
    
    '''
    지시사항 1번
    LeNet 구조를 완성하세요.
    '''
    # Conv 1 Layer
    model.add(Conv2D(filters=6, kernel_size=5, strides=1, activation=tf.nn.relu, input_shape=(img_size,img_size,3)))
    
    # Sub Sampling Layer (Max Pooling)
    model.add(MaxPool2D(pool_size=2, strides=2))
    
    # Conv 1 Layer
    model.add(Conv2D(filters=16, kernel_size=5, strides=1, activation=tf.nn.relu, input_shape=(16,16,3)))
            
    
    # Sub Sampling Layer (Max Pooling)
    model.add(MaxPool2D(pool_size=2, strides=2))
    
    # Fully Connected (FC) Layer와 연결하기 위한 Flatten
    model.add(Flatten())
    
    # FC1 Layer 
    model.add(Dense(units=120, activation=tf.nn.relu))
    
    
    # FC2 Layer
    model.add(Dense(units=84, activation=tf.nn.relu))
    
    
    # Output Softmax
    model.add(Dense(units=58, activation=tf.nn.softmax))
    
    
    return model
    

def main():
    
    train_images, test_images, train_labels, test_labels = get_images_and_preprocessing(128)

    print(train_images.shape)
    print(test_images.shape)
    
    
    # 지시사항 2에서 설정한 모델을 불러옵니다.
    model = LeNet(128)
    
    # 모델의 구조를 확인합니다.
    model.summary()
    
    # 컴파일러를 설정합니다.
    optimizer = tf.keras.optimizers.Adam(0.001)
    model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])
    
    # fit 함수를 사용하여 모델을 학습합니다.
    # 학습 수행 시 정보는 history에 저장합니다.
    history = model.fit(train_images,train_labels, epochs=20, batch_size=2, validation_data=(test_images, test_labels), verbose = 2)
    
    # evaluate 함수를 사용하여 테스트 데이터의 결과값을 저장합니다.
    loss, test_acc = model.evaluate(test_images,test_labels, verbose=2)
    
    print('\nTest Loss : {:.4f} | Test Accuracy : {}'.format(loss, test_acc))
    print('예측한 Test Data 클래스 : ',model.predict_classes(test_images)[:10])
    
    Visulaize([('LeNet', history)], 'loss')
     
#     오류해결해야함
#     Plotter(test_images, model)
    
    return test_acc

    
if __name__=='__main__':
    main()
# Out:
# (3698, 128, 128, 3)
# (2466, 128, 128, 3)
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 124, 124, 6)       456
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 62, 62, 6)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 58, 58, 16)        2416
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 29, 29, 16)        0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 13456)             0
# _________________________________________________________________
# dense_18 (Dense)             (None, 120)               1614840
# _________________________________________________________________
# dense_19 (Dense)             (None, 84)                10164
# _________________________________________________________________
# dense_20 (Dense)             (None, 58)                4930
# =================================================================
# Total params: 1,632,806
# Trainable params: 1,632,806
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1849/1849 - 38s - loss: 1.8901 - accuracy: 0.5068 - val_loss: 0.8709 - val_accuracy: 0.7543
# Epoch 2/20
# 1849/1849 - 37s - loss: 0.5113 - accuracy: 0.8629 - val_loss: 0.4354 - val_accuracy: 0.8881
# Epoch 3/20
# 1849/1849 - 37s - loss: 0.2379 - accuracy: 0.9319 - val_loss: 0.2973 - val_accuracy: 0.9319
# Epoch 4/20
# 1849/1849 - 37s - loss: 0.1296 - accuracy: 0.9657 - val_loss: 0.4287 - val_accuracy: 0.9157
# Epoch 5/20
# 1849/1849 - 37s - loss: 0.0999 - accuracy: 0.9767 - val_loss: 0.3638 - val_accuracy: 0.9461
# Epoch 6/20
# 1849/1849 - 38s - loss: 0.1065 - accuracy: 0.9740 - val_loss: 0.8300 - val_accuracy: 0.8589
# Epoch 7/20
# 1849/1849 - 39s - loss: 0.0832 - accuracy: 0.9767 - val_loss: 0.3402 - val_accuracy: 0.9457
# Epoch 8/20
# 1849/1849 - 38s - loss: 0.0418 - accuracy: 0.9884 - val_loss: 0.3665 - val_accuracy: 0.9380
# Epoch 9/20
# 1849/1849 - 39s - loss: 0.0620 - accuracy: 0.9865 - val_loss: 0.3714 - val_accuracy: 0.9530
# Epoch 10/20
# 1849/1849 - 38s - loss: 0.0478 - accuracy: 0.9900 - val_loss: 0.7202 - val_accuracy: 0.9286
# Epoch 11/20
# 1849/1849 - 38s - loss: 0.0573 - accuracy: 0.9889 - val_loss: 0.4497 - val_accuracy: 0.9538
# Epoch 12/20
# 1849/1849 - 37s - loss: 0.0820 - accuracy: 0.9843 - val_loss: 0.4633 - val_accuracy: 0.9461
# Epoch 13/20
# 1849/1849 - 38s - loss: 0.0637 - accuracy: 0.9873 - val_loss: 0.4733 - val_accuracy: 0.9473
# Epoch 14/20
# 1849/1849 - 38s - loss: 0.0262 - accuracy: 0.9946 - val_loss: 0.7892 - val_accuracy: 0.9124
# Epoch 15/20
# 1849/1849 - 38s - loss: 0.0637 - accuracy: 0.9854 - val_loss: 0.4798 - val_accuracy: 0.9562
# Epoch 16/20
# 1849/1849 - 38s - loss: 0.0273 - accuracy: 0.9930 - val_loss: 0.6112 - val_accuracy: 0.9546
# Epoch 17/20
# 1849/1849 - 38s - loss: 0.0487 - accuracy: 0.9941 - val_loss: 0.9345 - val_accuracy: 0.9051
# Epoch 18/20
# 1849/1849 - 38s - loss: 0.1289 - accuracy: 0.9832 - val_loss: 0.8013 - val_accuracy: 0.9420
# Epoch 19/20
# 1849/1849 - 38s - loss: 0.0624 - accuracy: 0.9908 - val_loss: 0.4662 - val_accuracy: 0.9554
# Epoch 20/20
# 1849/1849 - 38s - loss: 0.0139 - accuracy: 0.9978 - val_loss: 0.5423 - val_accuracy: 0.9517
# 78/78 - 2s - loss: 0.5423 - accuracy: 0.9517
#
# Test Loss : 0.5423 | Test Accuracy : 0.9517437219619751
# 예측한 Test Data 클래스 :  [23 28  6 35 28 50 12  4  7  4]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-62a1673dd97f> in <module>
#      74
#      75 if __name__=='__main__':
# ---> 76     main()
#
# <ipython-input-26-62a1673dd97f> in main()
#      65     print('예측한 Test Data 클래스 : ',model.predict_classes(test_images)[:10])
#      66
# ---> 67     Visulaize([('LeNet', history)], 'loss')
#      68
#      69 #     오류해결해야함
#
# NameError: name 'Visulaize' is not defined

# %% [markdown]
# # 4. VGGNet

# %% [markdown]
# ### 정확도 :

# %%
def conv(filters, kernel_size = 3, activation= tf.nn.relu, padding= 'same'):
    return keras.layers.Conv2D(filters = filters, kernel_size = kernel_size, activation= activation, padding= padding)

def VGG16(img_size):
    # Sequential 모델 선언
    model = keras.Sequential()
    
    '''
    지시사항 1번
    3 x 3 convolution만을 사용하여 VGG16 Net을 완성하세요.
    '''
    # 첫 번째 Conv Block
    # 입력 Shape는 ImageNet 데이터 세트의 크기와 같은 RGB 영상 (224 x 224 x 3)입니다
    model.add(Input((img_size, img_size, 3)))
    model.add(conv(64))
    model.add(conv(64))
    model.add(keras.layers.MaxPooling2D(pool_size = 2, strides = 2))
    
    # 두 번째 Conv Block
    model.add(conv(128))
    model.add(conv(128))
    model.add(keras.layers.MaxPooling2D(pool_size = 2, strides = 2))
    
    # 세 번째 Conv Block
    model.add(conv(256))
    model.add(conv(256))
    model.add(conv(256))
    model.add(keras.layers.MaxPooling2D(pool_size = 2, strides = 2))
    
    # 네 번째 Conv Block
    model.add(conv(512))
    model.add(conv(512))
    model.add(conv(512))
    model.add(keras.layers.MaxPooling2D(pool_size = 2, strides = 2))
    
    # 다섯 번째 Conv Block
    model.add(conv(512))
    model.add(conv(512))
    model.add(conv(512))
    model.add(keras.layers.MaxPooling2D(pool_size = 2, strides = 2))
    
    # Fully Connected Layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(4096, activation= tf.nn.relu))
    model.add(keras.layers.Dense(512, activation= tf.nn.relu))
    model.add(keras.layers.Dense(58, activation= tf.nn.softmax))
    
    return model
    

def main():
    
    train_images, test_images, train_labels, test_labels = get_images_and_preprocessing(128)

    print(train_images.shape)
    print(type(train_images))
    
    
    # 지시사항 2에서 설정한 모델을 불러옵니다.
    model = VGG16(128)
    
    # 모델의 구조를 확인합니다.
    model.summary()
    
    # 컴파일러를 설정합니다.
    optimizer = tf.keras.optimizers.Adam(0.001)
    model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])
    
    # fit 함수를 사용하여 모델을 학습합니다.
    # 학습 수행 시 정보는 history에 저장합니다.
    history = model.fit(train_images,train_labels, epochs=20, batch_size=256, validation_data=(test_images, test_labels), verbose = 2)
    
    # evaluate 함수를 사용하여 테스트 데이터의 결과값을 저장합니다.
    loss, test_acc = model.evaluate(test_images,test_labels, verbose=2)
    
    print('\nTest Loss : {:.4f} | Test Accuracy : {}'.format(loss, test_acc))
    print('예측한 Test Data 클래스 : ',model.predict_classes(test_images))
    
    Visualize([('VGGNet', history)], 'loss')
     
    Plotter(test_images, model)
    
    return test_acc

    
if __name__=='__main__':
    main()
# Out:
# (3698, 128, 128, 3)
# <class 'numpy.ndarray'>
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_66 (Conv2D)           (None, 128, 128, 64)      1792
# _________________________________________________________________
# conv2d_67 (Conv2D)           (None, 128, 128, 64)      36928
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_68 (Conv2D)           (None, 64, 64, 128)       73856
# _________________________________________________________________
# conv2d_69 (Conv2D)           (None, 64, 64, 128)       147584
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_70 (Conv2D)           (None, 32, 32, 256)       295168
# _________________________________________________________________
# conv2d_71 (Conv2D)           (None, 32, 32, 256)       590080
# _________________________________________________________________
# conv2d_72 (Conv2D)           (None, 32, 32, 256)       590080
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_73 (Conv2D)           (None, 16, 16, 512)       1180160
# _________________________________________________________________
# conv2d_74 (Conv2D)           (None, 16, 16, 512)       2359808
# _________________________________________________________________
# conv2d_75 (Conv2D)           (None, 16, 16, 512)       2359808
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_76 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# conv2d_77 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# conv2d_78 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 8192)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 4096)              33558528
# _________________________________________________________________
# dense_23 (Dense)             (None, 512)               2097664
# _________________________________________________________________
# dense_24 (Dense)             (None, 58)                29754
# =================================================================
# Total params: 50,400,634
# Trainable params: 50,400,634
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20

# %% [markdown]
# # 5. ResNet

# %% [markdown]
# ### 정확도 : 0.038

# %%
def identity_block(input_tensor, kernel_size, filters):
    
    filters1, filters2, filters3 = filters
    
    x = Conv2D(filters1, (1, 1))(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters2, kernel_size, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters3, (1, 1))(x)
    x = BatchNormalization()(x)
    
    '''
    지시사항 1번
    아래 내용을 채워 identity_block()을 완성하세요.
    '''
    # 입력(x) : input_tensor와 F(x) : x를 더해줍니다.
    # TODO : add()와 Activation() 메서드를 사용해서 relu(F(x) + x) 의 형태로 만들어보세요. 
    x = add([x, input_tensor])
    x = Activation('relu')(x)
    return x


def residual_block(input_tensor, kernel_size, filters, strides=(2, 2)):
    filters1 , filters2 , filters3 = filters
    
    # 입력 Feature Map의 Size를 1/2로 줄이는 대신 Feature map의 Dimension을 2배로 늘려줍니다.
    x = Conv2D(filters1, (1, 1), strides=strides)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters2, kernel_size, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters3, (1, 1))(x)
    x = BatchNormalization()(x)
    
    
    '''
    지시사항 2번
    아래 내용을 채워 residual_block()을 완성하세요.
    '''
    # TODO : Projection Shortcut Connection을 구현해보세요.
    # 1 x 1 Convolution 연산을 수행하여 Dimension을 2배로 증가시키고
    # 입력 Feature map의 size를 1/2로 축소시켜보세요.
    shortcut = Conv2D(filters3, (1, 1), strides=strides)(input_tensor)
    shortcut = BatchNormalization()(shortcut)

    # F(x) : x와 Shortcut Connection : shortcut을 더해줍니다.
    # TODO : add()와 Activation() 메서드를 사용해서 relu(F(x) + shortcut) 의 형태로 만들어보세요.
    x = add([x, shortcut])
    x = Activation('relu')(x)
    return x


def ResNet50(img_size):
    # 입력 이미지의 Shape을 정해줍니다.
    shape = (img_size,img_size,3)
    inputs = Input(shape)
    
    # 입력 영상의 크기를 줄이기 위한 Conv & Max-pooling
    x = ZeroPadding2D((3, 3))(inputs)
    x = Conv2D(64, (7, 7), strides=(2, 2))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2))(x)
    
    # 첫 번째 Residual Block (입력 영상 Size 2배 축소 / Dimension 2배 증가)
    x = residual_block(x, 3, [64, 64, 256], strides=(1, 1))
    x = identity_block(x, 3, [64, 64, 256])
    x = identity_block(x, 3, [64, 64, 256])
    
    
    # 두 번째 Residual Block (입력 영상 Size 2배 축소 / Dimension 2배 증가)
    x = residual_block(x, 3, [128, 128, 512])
    x = identity_block(x, 3, [128, 128, 512])
    x = identity_block(x, 3, [128, 128, 512])
    x = identity_block(x, 3, [128, 128, 512])
    
    # 세 번째 Residual Block (입력 영상 Size 2배 축소 / Dimension 2배 증가)
    x = residual_block(x, 3, [256, 256, 1024])
    x = identity_block(x, 3, [256, 256, 1024])
    x = identity_block(x, 3, [256, 256, 1024])
    x = identity_block(x, 3, [256, 256, 1024])
    x = identity_block(x, 3, [256, 256, 1024])
    x = identity_block(x, 3, [256, 256, 1024])
    
    # 네 번째 Residual Block (입력 영상 Size 2배 축소 / Dimension 2배 증가)
    x = residual_block(x, 3, [512, 512, 2048])
    x = identity_block(x, 3, [512, 512, 2048])
    x = identity_block(x, 3, [512, 512, 2048])

    # 마지막단에서 FC layer를 쓰지 않고 단순히 Averaging 합니다.
    x = AveragePooling2D((7, 7))(x)
    # x = GlobalAveragePooling2D()(x)
    x = Flatten()(x)
    # 1000개의 Class 구분
    x = Dense(58, activation='softmax')(x)
    
    # 모델 구성
    model = Model(inputs, x)
    return model

    

def main():
    
    train_images, test_images, train_labels, test_labels = get_images_and_preprocessing(224)

    print(train_images.shape)
    print(type(train_images))
    
    
    # 지시사항 2에서 설정한 모델을 불러옵니다.
    model = ResNet50(224)
    
    # 모델의 구조를 확인합니다.
    model.summary()
    
    # 컴파일러를 설정합니다.
    optimizer = tf.keras.optimizers.Adam(0.01)
    model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])
    
    # fit 함수를 사용하여 모델을 학습합니다.
    # 학습 수행 시 정보는 history에 저장합니다.
    history = model.fit(train_images,train_labels, epochs=5, batch_size=512, validation_data=(test_images, test_labels), verbose = 2)
    
    # evaluate 함수를 사용하여 테스트 데이터의 결과값을 저장합니다.
    loss, test_acc = model.evaluate(test_images,test_labels, verbose=2)
    
    print('\nTest Loss : {:.4f} | Test Accuracy : {}'.format(loss, test_acc))
#     print('예측한 Test Data 클래스 : ',model.predict_classes(test_images)[:10])
    
    Visualize([('ResNet', history)], 'loss')
     
#     Plotter(test_images, model)
    
    return test_acc

    
if __name__=='__main__':
    main()
# Out:
# (3698, 224, 224, 3)
# <class 'numpy.ndarray'>
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0           input_8[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 112, 112, 64) 9472        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 64) 256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 112, 112, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 55, 55, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 55, 55, 64)   4160        max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 55, 55, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 55, 55, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 55, 55, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 55, 55, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 55, 55, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 55, 55, 256)  16640       activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 55, 55, 256)  16640       max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 55, 55, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 55, 55, 256)  1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 55, 55, 256)  0           batch_normalization_3[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 55, 55, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 55, 55, 64)   16448       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 55, 55, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 55, 55, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 55, 55, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 55, 55, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 55, 55, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 55, 55, 256)  16640       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 55, 55, 256)  1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 55, 55, 256)  0           batch_normalization_7[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 55, 55, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 55, 55, 64)   16448       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 55, 55, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 55, 55, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 55, 55, 64)   36928       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 55, 55, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 55, 55, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 55, 55, 256)  16640       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 55, 55, 256)  1024        conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 55, 55, 256)  0           batch_normalization_10[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 55, 55, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 128)  32896       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 28, 28, 128)  512         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 28, 28, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 28, 28, 128)  147584      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 28, 28, 128)  512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 28, 28, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 28, 28, 512)  66048       activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 28, 28, 512)  131584      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 28, 28, 512)  2048        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 28, 28, 512)  2048        conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 28, 28, 512)  0           batch_normalization_13[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 28, 28, 512)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 28, 28, 128)  65664       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 128)  512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 28, 28, 128)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 28, 28, 128)  147584      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 128)  512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 28, 28, 512)  66048       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 28, 28, 512)  2048        conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 512)  0           batch_normalization_17[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 28, 28, 128)  65664       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 28, 28, 128)  512         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 28, 28, 128)  147584      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 28, 28, 128)  512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 28, 28, 512)  66048       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 28, 28, 512)  2048        conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 512)  0           batch_normalization_20[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 28, 28, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 28, 28, 128)  65664       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 28, 28, 128)  512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 28, 28, 128)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 28, 28, 128)  147584      activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 28, 28, 128)  512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 28, 28, 128)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 28, 28, 512)  66048       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 28, 28, 512)  2048        conv2d_36[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 512)  0           batch_normalization_23[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 14, 14, 256)  131328      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 14, 14, 256)  1024        conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 14, 14, 256)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 14, 14, 256)  590080      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 14, 14, 256)  1024        conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 14, 14, 256)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 1024) 263168      activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 14, 14, 1024) 525312      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 14, 14, 1024) 4096        conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 14, 14, 1024) 4096        conv2d_40[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 14, 14, 1024) 0           batch_normalization_26[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 14, 14, 1024) 0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 256)  262400      activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 14, 14, 256)  1024        conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 14, 14, 256)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 256)  590080      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 14, 14, 256)  1024        conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 14, 14, 256)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 1024) 263168      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 14, 14, 1024) 4096        conv2d_43[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 1024) 0           batch_normalization_30[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 14, 14, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 256)  262400      activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 14, 14, 256)  1024        conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 14, 14, 256)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 14, 14, 256)  590080      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 14, 14, 256)  1024        conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 14, 14, 256)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 14, 14, 1024) 263168      activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 14, 14, 1024) 4096        conv2d_46[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 1024) 0           batch_normalization_33[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 14, 14, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 14, 14, 256)  262400      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 14, 14, 256)  1024        conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 14, 14, 256)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 14, 14, 256)  590080      activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 14, 14, 256)  1024        conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 14, 14, 256)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 14, 14, 1024) 263168      activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 14, 14, 1024) 4096        conv2d_49[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 1024) 0           batch_normalization_36[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 14, 14, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 14, 14, 256)  262400      activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 14, 14, 256)  1024        conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 14, 14, 256)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 14, 14, 256)  590080      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 14, 14, 256)  1024        conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 14, 14, 256)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 14, 14, 1024) 263168      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 14, 14, 1024) 4096        conv2d_52[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 14, 14, 1024) 0           batch_normalization_39[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 14, 14, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 14, 14, 256)  262400      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 14, 14, 256)  1024        conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 14, 14, 256)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 14, 14, 256)  590080      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 14, 14, 256)  1024        conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 14, 14, 256)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 14, 14, 1024) 263168      activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 14, 14, 1024) 4096        conv2d_55[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 1024) 0           batch_normalization_42[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 14, 14, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 7, 7, 512)    524800      activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 7, 7, 512)    2048        conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 7, 7, 512)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 7, 7, 512)    2359808     activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 7, 7, 512)    2048        conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 7, 7, 512)    0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 7, 7, 2048)   1050624     activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 7, 7, 2048)   2099200     activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 7, 7, 2048)   8192        conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 7, 7, 2048)   8192        conv2d_59[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 7, 7, 2048)   0           batch_normalization_45[0][0]
#                                                                  batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 7, 7, 2048)   0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 7, 7, 512)    1049088     activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 7, 7, 512)    2048        conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 7, 7, 512)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 7, 7, 512)    2359808     activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 7, 7, 512)    2048        conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 7, 7, 512)    0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 7, 7, 2048)   1050624     activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 7, 7, 2048)   8192        conv2d_62[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 7, 7, 2048)   0           batch_normalization_49[0][0]
#                                                                  activation_42[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 7, 7, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 7, 7, 512)    1049088     activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 7, 7, 512)    2048        conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 7, 7, 512)    0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 7, 7, 512)    2359808     activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 7, 7, 512)    2048        conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 7, 7, 512)    0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 7, 7, 2048)   1050624     activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 7, 7, 2048)   8192        conv2d_65[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 2048)   0           batch_normalization_52[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 7, 7, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 2048)   0           activation_48[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 2048)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 58)           118842      flatten_9[0][0]
# ==================================================================================================
# Total params: 23,706,554
# Trainable params: 23,653,434
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# Epoch 1/5
# 8/8 - 1084s - loss: 6.2122 - accuracy: 0.0592 - val_loss: 2139911540117925265408.0000 - val_accuracy: 0.0827
# Epoch 2/5
# 8/8 - 1065s - loss: 4.4359 - accuracy: 0.0990 - val_loss: 1042973789897711681536.0000 - val_accuracy: 0.0381
# Epoch 3/5
# 8/8 - 1067s - loss: 3.9166 - accuracy: 0.1036 - val_loss: 32775091423723651072.0000 - val_accuracy: 0.0381
# Epoch 4/5
# 8/8 - 1128s - loss: 3.6755 - accuracy: 0.0900 - val_loss: 59303233385922560.0000 - val_accuracy: 0.0381
# Epoch 5/5
# 8/8 - 1081s - loss: 3.5721 - accuracy: 0.1444 - val_loss: 15716738108751872.0000 - val_accuracy: 0.0381
# 78/78 - 136s - loss: 15716737035010048.0000 - accuracy: 0.0381
#
# Test Loss : 15716737035010048.0000 | Test Accuracy : 0.03811841085553169
