# %%
from gensim.models import word2vec
import list_file

'''
지시사항 1번
   CBOW 방식의 Word2Vec 모델을
   반환하는 CBOW 함수를 완성하세요.
'''

def CBOW(sentences):

    model_cbow = word2vec.Word2Vec(sentences, size=300, min_count=1, window=10, sg=0)
    
    print(model_cbow.wv.vectors.shape)
    
    return model_cbow

'''
지시사항 2번
   Skip-Gram 방식의 Word2Vec 모델을
   반환하는 Skip_Gram 함수를 완성하세요.
'''

def Skip_Gram(sentences):
    
    model_skipgram = word2vec.Word2Vec(sentences, size=300, min_count=1, window=10, sg=1)
    
    return model_skipgram

'''
지시사항 3번
   각 모델의 결괏값을 정의하세요.
'''

def main():
    
    sen1, sen2 = list_file.sen1(), list_file.sen2()
    
    sentences = [sen1, sen2]
    
    cbow = CBOW(sentences)
    skipgram = Skip_Gram(sentences)
    
    idx2word_set_cbow = cbow.wv.index2word
    idx2word_set_skipgram = skipgram.wv.index2word
    
    
    print('CBOW: ', idx2word_set_cbow)
    print('\nSkip-Gram: ', idx2word_set_skipgram)
    
    return idx2word_set_cbow, idx2word_set_skipgram

if __name__ == '__main__':
    main()
# Out:
# (276, 300)
# CBOW:  [',', '이', '에', '을', '도', '은', '는', '가', '부인', '서', '를', '피란', '라', '고', '의', '마음', '다', '없고', '못', '하는', '한', '아니', '과', '하여', '니', '겁', '사람', '밤', '소리', '그', '호랑이', '귀신', '와', '저', '산', '.', '평양성', '데', '하고', '얼굴', '가도', '길이', '로', '길', '나', '사나이', '힘', '없는', '에서', '고생', '나를', '될', '중', '서로', '아', '듯', '하더', '하늘', '다시', '아닌', '줄', '무섭', '더니', '든지', '이나', '놈', '일', '오고', '것', '내', '단', '이라', '볕', '붙들어', '듯이', '걸음걸이', '가지', '사는', '갔', '다가', '식구', '에그', '깜깜', '이리', '저리', '없으', '어디', '가면', '찾', '을까', '다리', '좋', '이언', '마는', '이러한', '산비탈', '새고', '찾아다니', '려', '하면', '이렇게', '대단하거', '든', '많고', '다녀', '보지', '하던', '여편네', '찾아다니느', '오죽', '까', '듣고', '난리', '가다가', '부부', '잃고', '종적', '모르니', '살', '생이별', '도와', '만나', '본', '반가운', '질렀더', '자기', '남편', '깨닫', '제', '계집', '알', '았', '더라', '나서', '간이', '서늘하고', '남자', '선녀', '만난', '흥김', '겁김', '가슴', '두근거리', '면서', '숨소리', '크', '목소리', '나온', '아까', '지금', '나와', '잡아먹', '잡아', '그런', '뜻밖', '기다리', '눈', '보이는', '말', '별', '뿐이', '요', '에는', '죄', '몸', '몹쓸', '두', '뿐', '모란봉', '떨어지는', '저녁', '뉘엿뉘엿', '넘어가는', '햇빛', '매고', '싶은', '매', '지는', '숨', '턱', '닿은', '갈팡질팡', '나이', '삼십이', '락말락', '분', '따고', '넣은', '흰', '인정', '없이', '뜨겁', '게', '내리', '쪼', '가을', '익어', '선앵둣빛', '되', '허둥지둥', '옷', '흘러내려', '젖가슴', '드러나고', '치맛', '자락', '땅', '질질', '끌려', '걸음', '걷는', '대로', '치마', '밟', '히', '아무리', '급한', '라도', '멀리', '허둥', '거리', '기만', '북문', '안', '며칠', '전', '에도', '있', '수', '촌', '갓집', '으로', '단칸', '방', '주인', '손', '여덟', '이틀', '앉아', '새우고', '하릴없이', '도로', '온', '지', '불과', '수일', '전이', '그때', '죽어', '하였', '오늘', '새벽', '부터', '총', '천지', '뒤집', '어', '놓고', '사면', '산꼭대기', '들', '가운데', '불비', '쏟아지니', '밝기', '기다려', '떠났', '는데', '무것', '가진', '젊은', '내외', '어린', '딸', '옥련', '세']
#
# Skip-Gram:  [',', '이', '에', '을', '도', '은', '는', '가', '부인', '서', '를', '피란', '라', '고', '의', '마음', '다', '없고', '못', '하는', '한', '아니', '과', '하여', '니', '겁', '사람', '밤', '소리', '그', '호랑이', '귀신', '와', '저', '산', '.', '평양성', '데', '하고', '얼굴', '가도', '길이', '로', '길', '나', '사나이', '힘', '없는', '에서', '고생', '나를', '될', '중', '서로', '아', '듯', '하더', '하늘', '다시', '아닌', '줄', '무섭', '더니', '든지', '이나', '놈', '일', '오고', '것', '내', '단', '이라', '볕', '붙들어', '듯이', '걸음걸이', '가지', '사는', '갔', '다가', '식구', '에그', '깜깜', '이리', '저리', '없으', '어디', '가면', '찾', '을까', '다리', '좋', '이언', '마는', '이러한', '산비탈', '새고', '찾아다니', '려', '하면', '이렇게', '대단하거', '든', '많고', '다녀', '보지', '하던', '여편네', '찾아다니느', '오죽', '까', '듣고', '난리', '가다가', '부부', '잃고', '종적', '모르니', '살', '생이별', '도와', '만나', '본', '반가운', '질렀더', '자기', '남편', '깨닫', '제', '계집', '알', '았', '더라', '나서', '간이', '서늘하고', '남자', '선녀', '만난', '흥김', '겁김', '가슴', '두근거리', '면서', '숨소리', '크', '목소리', '나온', '아까', '지금', '나와', '잡아먹', '잡아', '그런', '뜻밖', '기다리', '눈', '보이는', '말', '별', '뿐이', '요', '에는', '죄', '몸', '몹쓸', '두', '뿐', '모란봉', '떨어지는', '저녁', '뉘엿뉘엿', '넘어가는', '햇빛', '매고', '싶은', '매', '지는', '숨', '턱', '닿은', '갈팡질팡', '나이', '삼십이', '락말락', '분', '따고', '넣은', '흰', '인정', '없이', '뜨겁', '게', '내리', '쪼', '가을', '익어', '선앵둣빛', '되', '허둥지둥', '옷', '흘러내려', '젖가슴', '드러나고', '치맛', '자락', '땅', '질질', '끌려', '걸음', '걷는', '대로', '치마', '밟', '히', '아무리', '급한', '라도', '멀리', '허둥', '거리', '기만', '북문', '안', '며칠', '전', '에도', '있', '수', '촌', '갓집', '으로', '단칸', '방', '주인', '손', '여덟', '이틀', '앉아', '새우고', '하릴없이', '도로', '온', '지', '불과', '수일', '전이', '그때', '죽어', '하였', '오늘', '새벽', '부터', '총', '천지', '뒤집', '어', '놓고', '사면', '산꼭대기', '들', '가운데', '불비', '쏟아지니', '밝기', '기다려', '떠났', '는데', '무것', '가진', '젊은', '내외', '어린', '딸', '옥련', '세']
